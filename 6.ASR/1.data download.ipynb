# %% [markdown]
# ### Install gdown

# %%
# !pip install gdown

# %% [markdown]
# ### Download KsponSpeech samples

# %%
# !gdown https://drive.google.com/uc?id=18bqkhp_jyAG8ijRGzpJgPHk7eSMuwpYy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18bqkhp_jyAG8ijRGzpJgPHk7eSMuwpYy
# To: /home/gaudio/ste/projects/lectures/aiffel/6.ASR/ks.zip
# 100%|████████████████████████████████████████| 124M/124M [00:29<00:00, 4.25MB/s]

# %% [markdown]
# ### Unzip

# %%
# !unzip ks.zip -d dataset
# Out:
# Archive:  ks.zip
#  extracting: dataset/KsponSpeech_000001.txt
#   inflating: dataset/KsponSpeech_000001.wav
#   inflating: dataset/KsponSpeech_000002.txt
#   inflating: dataset/KsponSpeech_000002.wav
#   inflating: dataset/KsponSpeech_000003.txt
#   inflating: dataset/KsponSpeech_000003.wav
#  extracting: dataset/KsponSpeech_000004.txt
#   inflating: dataset/KsponSpeech_000004.wav
#   inflating: dataset/KsponSpeech_000005.txt
#   inflating: dataset/KsponSpeech_000005.wav
#  extracting: dataset/KsponSpeech_000006.txt
#   inflating: dataset/KsponSpeech_000006.wav
#   inflating: dataset/KsponSpeech_000007.txt
#   inflating: dataset/KsponSpeech_000007.wav
#  extracting: dataset/KsponSpeech_000008.txt
#   inflating: dataset/KsponSpeech_000008.wav
#  extracting: dataset/KsponSpeech_000009.txt
#   inflating: dataset/KsponSpeech_000009.wav
#  extracting: dataset/KsponSpeech_000010.txt
#   inflating: dataset/KsponSpeech_000010.wav
#  extracting: dataset/KsponSpeech_000011.txt
# ...
