# %%
import numpy as np
import pickle
from tensorflow.keras.preprocessing.text import Tokenizer 

# loading
with open('data/src_tokenizer.pickle', 'rb') as handle:
    src_tokenizer = pickle.load(handle)
    
# loading
with open('data/tar_tokenizer.pickle', 'rb') as handle:
    tar_tokenizer = pickle.load(handle)
    
print('done')
# Out:
# done

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %%
text_max_len = 50
src_vocab = 8000
tar_vocab = 2000

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
# 디코더 설계
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
import urllib.request

urllib.request.urlretrieve("https://raw.githubusercontent.com/thushv89/attention_keras/master/src/layers/attention.py", filename="attention.py")
from attention import AttentionLayer

# %%
# 어텐션 층(어텐션 함수)
attn_layer = AttentionLayer(name='attention_layer')
# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# %%
# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()

import tensorflow as tf
model.load_weights(tf.train.latest_checkpoint('./training_checkpoints'))
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 128)      1024000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    256000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 256),  131328      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 512)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, None, 2000)   1026000     concat_layer[0][0]
# ==================================================================================================
# Total params: 4,276,432
# Trainable params: 4,276,432
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
summary_max_len = 8
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if (i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if ((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

# %%
import numpy as np
data = np.load('data/preprocess2.npz', allow_pickle=True)

encoder_input_train = data['encoder_input_train']
encoder_input_test = data['encoder_input_test']
decoder_input_train = data['decoder_input_train']

decoder_target_train = data['decoder_target_train']
decoder_input_test = data['decoder_input_test']
decoder_target_test = data['decoder_target_test']

# %%
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : pack dogs florida dinosaurs make great chew toys three love every time basset hound let outside stop mouth sneak toy outside would get lost
# 실제 요약 : happy dogs
# 예측 요약 :  great best
#
#
# 원문 : tastes amazingly great vanilla flavor definitely best chai probably best one comes top list
# 실제 요약 : delicious
# 예측 요약 :  great taste
#
#
# 원문 : daughter eating since months old always loved loves flavors convenient
# 실제 요약 : year old loves it
# 예측 요약 :  it excellent so nice
#
#
# 원문 : great deal yummy candy gun boys loved eating candy lol
# 실제 요약 : kids love these
# 예측 요약 :  great delicious
#
#
# 원문 : found local fell love immediately quite consistency standard jerky something make absolutely delicious came fresh easy eat dry chewy peppered enough somewhat sweet taste well glad able find amazon instead go take trip think get used consistency compare find tasty treat well
# 실제 요약 : oh how love these
# 예측 요약 :  it in
#
#
# 원문 : dog loves booda bones bit pricy give couple week special treat continue buying amazon best price
# 실제 요약 : bone dog treats pack
# 예측 요약 :  dogs love nice
#
#
# 원문 : buying milk hot chocolate months one best even got laws hooked absolutely love great price great product
# 실제 요약 : amazon nut
# 예측 요약 :  for you food
#
#
# 원문 : soup full chunks potatoes tiny pieces clams basically potato soup would never buy
# 실제 요약 : where are the
# 예측 요약 :  not on good on coconut
#
#
# 원문 : product comes within beautiful lightly brown biodegradable box attention detail astounding makes conversation piece regardless circumstances perfect gift wait try delicious flavors
# 실제 요약 : beautiful
# 예측 요약 :  great delicious
#
#
# 원문 : like rich chocolate crunchy granola yummy complaint would seemingly chocolate chips unsure clumps chocolate covered granola chips supposed either way worked put bowl gone matter minutes year old grandmother loved much year old requested many times think would delightful even milk cereal buy
# 실제 요약 : everyone loved this
# 예측 요약 :  you
#
#
# 원문 : used product years first time amazon glad far best pancake waffle mix market bar none
# 실제 요약 : best breakfast
# 예측 요약 :  good delicious
#
#
# 원문 : like french vanilla available extra mile store looking towards similar taste one feels like chocolate drink expecting bit coffee taste add instant coffee mix hot milk get flavour wanted would try brand next time
# 실제 요약 : not so
# 예측 요약 :  it in
#
#
# 원문 : love good coffee hate strong taste perfect excellent smooth flavor wonderful aroma writing makes crave cup unfortunately packaging ridiculous deal impossible open bag pulling seal apart resort cutting open scissors created sharp edges heavy foil better packaging would definitely rate stars
# 실제 요약 : very good coffee
# 예측 요약 :  not the for
#
#
# 원문 : smooth used filters smell inviting used measurements package used per cup worked fine like coffee tasteful
# 실제 요약 : decaf coffee
# 예측 요약 :  great coffee
#
#
# 원문 : researched quite bit formulas really set organic formula one first choice received son actually liked happy bloating gas likes taste definitely would recommend
# 실제 요약 : very happy with purchase
# 예측 요약 :  dogs love nice
#
#
# 원문 : like muffin packs whole mix makes muffins total many mixes make small household stuck way many muffins better expected soft flavorful baked perfectly also use small amount cooking spray muffin pop right pan cooking healthiest food overall would recommend mix
# 실제 요약 : simple muffins that anyone can easily make
# 예측 요약 :  great best the like
#
#
# 원문 : boxes got raisins average cereal got raisins pretty high looking box raisins rather cereal go
# 실제 요약 : its not cereal its raisin
# 예측 요약 :  good delicious
#
#
# 원문 : pack box sardines best ones ever diabetic candy bar lunch set day lunch work
# 실제 요약 : best way to have my lunch
# 예측 요약 :  great delicious
#
#
# 원문 : anchovies go seem great tasting think taste great salads pizza full flavored anchovies lovers like
# 실제 요약 : great
# 예측 요약 :  great delicious
#
#
# 원문 : mother load canned clams juice cups cups chopped clams found sand able use every last drop juices simply recipe best white clam sauce ever made
# 실제 요약 : white clam sauce
# 예측 요약 :  great taste
#
#
# 원문 : purchased cent store disappointed taste super sweet little dark chocolate flavor even creamy like milk chocolate guess would rather save calories better tasting chocolate
# 실제 요약 : store quality
# 예측 요약 :  not on good on coconut
#
#
# 원문 : think one best brands best juice buy couple lids come leaking please bring back
# 실제 요약 : love this stuff
# 예측 요약 :  for food
#
#
# 원문 : good light taste strong flavoring little aftertaste go easy mm definitely happy purchase
# 실제 요약 : yum
# 예측 요약 :  not treats
#
#
# 원문 : favorite brown rice terms flavor consistency enjoy eating many different ways
# 실제 요약 : favorite brown rice
# 예측 요약 :  great taste
#
#
# 원문 : pediatrician told include form meat dinner baby unfortunately two four varieties include meat think summer vegetable included dinner variety pack vegetable variety pack also chicken sweet potato extremely runny hard feed baby
# 실제 요약 : just okay
# 예측 요약 :  it one so my
#
#
# 원문 : little jack russell love durable dental dinosaurs usually buy three time last three four months great entertainment yr old dogs teeth sparkling every morning like brush teeth anyhow dogs love hard chew toys
# 실제 요약 : my dogs love these
# 예측 요약 :  love my
#
#
# 원문 : coffee full rich flavor exactly dark roast taste like swiss water process decaf must
# 실제 요약 : full flavored brew
# 예측 요약 :  good coffee
#
#
# 원문 : really like product would say tastes like honey nut would say corn taste like really really sweet right
# 실제 요약 : honey nut
# 예측 요약 :  good
#
#
# 원문 : great snacks similar veggie sticks often get local supermarket shape bit middle makes lighter unfortunately easier eat lot
# 실제 요약 : light and crispy
# 예측 요약 :  not treats
#
#
# 원문 : purchased wedding last month put champagne give drinks pretty decoration touch pink worked great flowers tasty look really pretty
# 실제 요약 : great for
# 예측 요약 :  great delicious
#
#
# 원문 : enjoyable sparkling water reasonably priced lots carbonation suggest others ordered also like talking rain sparkling natural
# 실제 요약 : love this
# 예측 요약 :  good taste
#
#
# 원문 : expected sugar java mocha flavor overwhelms cinnamon flavor sticks seem sugar sprinkled added would order
# 실제 요약 : not as sweet as expected
# 예측 요약 :  good delicious
#
#
# 원문 : really wanted love illy issimo caffe expresso style drink however simply expresso used product strong still richness expresso received fresh cafe smell expresso overwhelming also like taste expresso guess good product want expresso cannot leave home office calories per cup excellent dieters drink product ever
# 실제 요약 : too strong not enough flavor
# 예측 요약 :  great best the like
#
#
# 원문 : taste good easy stomach running help keep energy long runs love
# 실제 요약 : so yummy
# 예측 요약 :  good snack
#
#
# 원문 : every year put together treat bags trick get plus every year bubble one gum put cheap price great taste kids adults love
# 실제 요약 : bubble
# 예측 요약 :  great bar
#
#
# 원문 : purchased pack flavors daughter cannot devour quick enough enjoyed flavors really seems enjoy apple blueberry easily grab fruit even though teeth goes smoothly feel better feeding organic fruit safe win win situation
# 실제 요약 : super tasty
# 예측 요약 :  love these
#
#
# 원문 : make sure keep house huge chocolate cravings feel bad eating super sweet satisfy craving much healthier hershey bar get bj wholesale club around fun pop mouth everyone know tried thinks great
# 실제 요약 : luv these
# 예측 요약 :  good coffee
#
#
# 원문 : ordered new york expresso coffe beans candy buffet daughters wedding everyone loved talked without doubt favorite glad found amazon may order around
# 실제 요약 : big hit
# 예측 요약 :  great delicious
#
#
# 원문 : brew bitter strong makes good cup coffee like mild taste
# 실제 요약 : one of the better cups
# 예측 요약 :  great coffee
#
#
# 원문 : first shipment ordered last shipment bars went ounce ounce bar says chocolate peanut chocolate peanut butter picture looks packages disappointed shipment opened boxes realized difference could send back
# 실제 요약 : wrong size bars sent
# 예측 요약 :  product
#
#
# 원문 : could find product grocery store found line easy take work school live rural area buying bulk means fewer trips grocery store
# 실제 요약 : calorie snack mix caramel ounce packages
# 예측 요약 :  not the for
#
#
# 원문 : wow chocolate raspberry flavored coffee absolute best ever honestly say tried quite time course price cannot beat unless find someone wants sell fell back delivery truck
# 실제 요약 : chocolate
# 예측 요약 :  for coffee food
#
#
# 원문 : great product amazon way expensive get ounce bags walmart per back lbs pounds would rather small bags far best gummi
# 실제 요약 : awesome taste high amazon price
# 예측 요약 :  great coffee
#
#
# 원문 : dogs loved sure helped hips keep giving chicken strips find
# 실제 요약 : dogs loved them
# 예측 요약 :  good
#
#
# 원문 : name literally yoo hoo basically slightly watered chocolate milk ages thought would share family happen biggest fan gross anything
# 실제 요약 : it is
# 예측 요약 :  not really coconut
#
#
# 원문 : put together cups everything went well coffee cups along filter putting kcup coffee machine would drip checked everything put together correctly took made cups son coffee maker keurig brand also thing starts ok made drips coffee tried two different keurig work make holes right places
# 실제 요약 : disposable cups
# 예측 요약 :  product
#
#
# 원문 : mallomars graham cracker circle topped dollop covered thin coat dark chocolate flavor satisfying texture biting cloud happiness really people like lot available enjoy year around think pretty fine arrived fresh good condition giving stars chocolatey
# 실제 요약 : mallomars cold treat since
# 예측 요약 :  the for
#
#
# 원문 : great purchase huge bag craving years
# 실제 요약 : sweet
# 예측 요약 :  great
#
#
# 원문 : bought sorts nylabone chew toys rings bones tree stick dinosaurs rex far girl favorite easy hold chew girl chihuahua terrier mix chewed rex bones buy back ups place town sells sell buying amazon
# 실제 요약 : my girl favorite
# 예측 요약 :  not on described
#
#
# 원문 : liked idea small popcorn pops really well popper much popcorn flavor pretty bummed
# 실제 요약 : pops well not much flavor
# 예측 요약 :  good

# %%
print('done')
# Out:
# done
